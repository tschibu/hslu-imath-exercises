% %% [markdown]
% # 11 Plotting with Octave

% %% [markdown]
% $y = sinx$ in the interval $[0,2π]$.

% %%
x = linspace(0, 2*pi, 100);
y = sin(x);
plot(x, y, ';sin(x);');
title ('sin(x)');
grid on
xlabel ('x')
ylabel ('y')

% %% [markdown]
% ## Countourplots

% %%
x = linspace(-2 * pi,2 * pi);
y = linspace(0,4 * pi);
[X,Y] = meshgrid(x,y);
Z = X.^2-Y.^2;

figure
contour(X,Y,Z)

% %% [markdown]
% ## Plot Graph

% %%
[X,Y] = meshgrid(-2:.2:2, -2:.2:2);
Z = X .* exp(-X.^2 - Y.^2);
mesh(X,Y,Z)
surf(X,Y,Z)
meshc(X,Y,Z)
axis off
